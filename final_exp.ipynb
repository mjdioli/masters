# %%
import utils_clean
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
missing_pct = [0, 25,50,75, 90, 95]

# %%
data = utils_clean.run("two_year_recid", "priors_count", "gender_factor", models = ["log_reg", "rf_cat", "knn"], dataset = "recid", n_runs = 4)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]c:\Users\mariu\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   0%|          | 0/4 [21:16<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7980/4177937902.py in <module>
# ----> 1 data = utils_clean.run("two_year_recid", "priors_count", "gender_factor", models = ["log_reg", "rf_cat", "knn"], dataset = "recid", n_runs = 4)
#
# c:\Users\mariu\masters\utils_clean.py in run(response, missing_col, sensitive, models, dataset, n_runs)
#     191                 data_mcar_missing = train.copy()
#     192                 data_mar_missing = train.copy()
# --> 193             else:"""
#     194             data_mcar_missing = data_remover_cat(
#     195                     train, missing_col, alph, noise, missing_pct = missing_pct, missingness="mcar")
#
# ~\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\_testing.py in wrapper(*args, **kwargs)
#     311             with warnings.catch_warnings():
#     312                 warnings.simplefilter("ignore", self.category)
# --> 313                 return fn(*args, **kwargs)
#     314
#     315         return wrapper
#
# c:\Users\mariu\masters\utils_clean.py in impute(dataframe, response, missing_col, sensitive_col, impute)
#     140     elif impute == "knn":
#     141         pass
# --> 142     elif len(impute_split) ==3 :
#     143         flr = FairLogisticRegression(fairness_metric = "eo_sum",lam = int(impute_split[-1])/100)
#     144         obs_data = data.dropna()
#
# c:\Users\mariu\masters\fair_logistic_reg.py in fit(self, x, y, z, epochs, data, missing)
#      54             else:
#      55
# ---> 56                 fair_error_w = self.fair_grad(self.weights, x.transpose(),y,z,self.fairness_metric)
#      57             #print("difference_error: ", error_w-fair_error_w)
#      58             #Scaling the fairness error
#
# c:\Users\mariu\masters\fair_logistic_reg.py in fair_grad(self, weights, x_transpose, true, prot, metric)
#     150     def fair_grad(self, weights,  x_transpose,true, prot, metric="spd"):
#     151         g = grad(self.fairness, 0)
# --> 152         return g(weights, x_transpose, true, prot, metric)
#     153
#     154     def fairness_model(self, weights,weights_pred, x_transpose, true, prot, model, data, missing, metric="spd"):
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\wrap_util.py in nary_f(*args, **kwargs)
#      18             else:
#      19                 x = tuple(args[i] for i in argnum)
# ---> 20             return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#      21         return nary_f
#      22     return nary_operator
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\differential_operators.py in grad(fun, x)
#      23     arguments as `fun`, but returns the gradient instead. The function `fun`
#      24     should be scalar-valued. The gradient has the same type as the argument."""
# ---> 25     vjp, ans = _make_vjp(fun, x)
#      26     if not vspace(ans).size == 1:
#      27         raise TypeError("Grad only applies to real scalar-output functions. "
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\wrap_util.py in unary_f(x)
#      13                 else:
#      14                     subargs = subvals(args, zip(argnum, x))
# ---> 15                 return fun(*subargs, **kwargs)
#      16             if isinstance(argnum, int):
#      17                 x = args[argnum]
#
# c:\Users\mariu\masters\fair_logistic_reg.py in fairness(self, weights, x_transpose, true, prot, metric)
#     146             return self.spd(pred, prot)
#     147         else:
# --> 148             return self.eo_sum(pred,prot,true)
#     149
#     150     def fair_grad(self, weights,  x_transpose,true, prot, metric="spd"):
#
# c:\Users\mariu\masters\fair_logistic_reg.py in eo_sum(self, pred, prot, true)
#     126         z0_y0 = [y_hat for y_hat, z, y in zip(
#     127             pred, prot, true) if z == 0 and y == 0]
# --> 128         z1_y1 = [y_hat for y_hat, z, y in zip(
#     129             pred, prot, true) if z == 1 and y == 1]
#     130         z0_y1 = [y_hat for y_hat, z, y in zip(
#
# c:\Users\mariu\masters\fair_logistic_reg.py in <listcomp>(.0)
#     126         z0_y0 = [y_hat for y_hat, z, y in zip(
#     127             pred, prot, true) if z == 0 and y == 0]
# --> 128         z1_y1 = [y_hat for y_hat, z, y in zip(
#     129             pred, prot, true) if z == 1 and y == 1]
#     130         z0_y1 = [y_hat for y_hat, z, y in zip(
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\tracer.py in f_wrapped(*args, **kwargs)
#      35     @wraps(f_raw)
#      36     def f_wrapped(*args, **kwargs):
# ---> 37         boxed_args, trace, node_constructor = find_top_boxed_args(args)
#      38         if boxed_args:
#      39             argvals = subvals(args, [(argnum, box._value) for argnum, box in boxed_args])
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\tracer.py in find_top_boxed_args(args)
#      68     top_node_type = None
#      69     for argnum, arg in enumerate(args):
# ---> 70         if isbox(arg):
#      71             trace = arg._trace
#      72             if trace > top_trace:
#
# ~\AppData\Roaming\Python\Python39\site-packages\autograd\tracer.py in <lambda>(x)
#     121
#     122 box_types = Box.types
# --> 123 isbox  = lambda x: type(x) in box_types  # almost 3X faster than isinstance(x, Box)
#     124 getval = lambda x: getval(x._value) if isbox(x) else x
#
# KeyboardInterrupt:

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|fair_reg_50'], label = "fair_reg_50")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|fair_reg_75'], label = "fair_reg_75")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|fair_reg_99'], label = "fair_reg_99")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|fair_reg_95'], label = "fair_reg_95")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|mice_def'], label = "mice_def")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|mean'], label = "mean")
plt.plot(missing_pct, data["Averaged results"]['mcar|acc|log_reg|cca'], label = "cca")
plt.legend()
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|fair_reg_50'], label = "fair_reg_50")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|fair_reg_75'], label = "fair_reg_75")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|fair_reg_99'], label = "fair_reg_99")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|fair_reg_95'], label = "fair_reg_95")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|mice_def'], label = "mice_def")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|mean'], label = "mean")
plt.plot(missing_pct, data["Averaged results"]['mar|acc|log_reg|cca'], label = "cca")
plt.legend()
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|fair_reg_50'], label = "fair_reg_50")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|fair_reg_75'], label = "fair_reg_75")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|fair_reg_99'], label = "fair_reg_99")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|fair_reg_95'], label = "fair_reg_95")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|mice_def'], label = "mice_def")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|mean'], label = "mean")
plt.plot(missing_pct, data["Averaged results"]['mar|eosum|log_reg|cca'], label = "cca")
plt.legend()
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|fair_reg_50'], label = "fair_reg_50")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|fair_reg_75'], label = "fair_reg_75")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|fair_reg_99'], label = "fair_reg_99")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|fair_reg_95'], label = "fair_reg_95")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|mice_def'], label = "mice_def")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|mean'], label = "mean")
plt.plot(missing_pct, data["Averaged results"]['mcar|eosum|log_reg|cca'], label = "cca")
plt.legend()
plt.show()

# %%
import os
from pathlib import Path
savepath = "final_experiment/"
if not os.path.isdir(Path("final_experiment/")):
    os.mkdir(Path(savepath))
    
import json
with open(Path(savepath), 'w') as f:
    json.dump(data, f, indent=1)
